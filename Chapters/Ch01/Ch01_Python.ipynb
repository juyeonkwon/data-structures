# %% [markdown]
# # 파이썬이란?
# *  AI와 빅데이터의 부상과 함께 최근 각광받고 있는 언어
# * 1991년에 귀도 반 로섬(Guido van Rossum)
# * 문법이 쉬움. 코드를 보면 직관적으로 알 수 있는 부분이 많음
# * 인터프리터 방식 🡸🡺 컴파일 방식
# * 스크립트 모드 지원
# * 통합개발환경: IDLE, 주피터 노트북, 파이참, 비주얼 스튜디오

# %% [markdown]
# # 자료형, 리터럴과 변수
#
# * 파이썬 예약어
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * 리터럴과 자료형
# ![50-1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # 변수
# + 변수 생성
#
#  ![52-1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# * 변수동작 이해하기
#
# ![image.png](data:image/png;base64,...)

# %%
number = 132
number = number + 8
pi = 3.14
comp = 1 + 2j
isValid = True
msg = 'game over !!! '
A = [0, 1, 1, 2, 3, 5, 8, 13 ]

# %%
A[4] = 10
print(A)

# %%
print(comp)

# %% [markdown]
# 1. 나눗셈 연산자 변경
# * 연산자: 실수 나눗셈을 수행합니다. 결과는 항상 실수입니다.
# * 연산자: 정수 나눗셈 (floor division)을 수행합니다. 결과는 소수점 이하를 버린 정수입니다.

# %%
# 실수 나눗셈
print(7 / 2)  # 출력: 3.5

# 정수 나눗셈 (floor division)
print(7 // 2)  # 출력: 3

# %% [markdown]
# 2. 이항 연산자 ** 추가
# * "**" 연산자는 거듭제곱을 나타냅니다.

# %%
# 2의 3제곱
print(2 ** 3)  # 출력: 8

# %% [markdown]
# 3. 단항 연산자 ++, -- 제공되지 않음
# * 파이썬은 C나 Java와 달리 ++, -- 단항 연산자를 지원하지 않습니다.
# * 대신, 증가 또는 감소 연산을 할 때 += 1 또는 -= 1을 사용합니다.

# %%
i -= 1

i = i - 1

# %%
x = 5
x += 1  # x를 1 증가
print(x)  # 출력: 6

x -= 1  # x를 1 감소
print(x)  # 출력: 5

# %% [markdown]
# ### 4. 관계 연산자
# * 관계 연산자는 두 값을 비교하는 데 사용됩니다:
#   * `>`: 크다
#   * `<`: 작다
#   * `>=`: 크거나 같다
#   * `<=`: 작거나 같다
#   * `==`: 같다
#   * `!=`: 같지 않다

# %%
a = 10
b = 20
print(a > b)  # 출력: False
print(a != 10)  # 출력: True

# %% [markdown]
# ### 5. 불리언 연산자
# * 파이썬에서는 논리 연산을 다음과 같이 수행합니다:
#   * `or`: 논리합 (||)
#   * `and`: 논리곱 (&&)
#   * `not`: 부정 (!)

# %%
x = True
y = False

print(x or y)  # 출력: True
print(x and y)  # 출력: False
print(not x)  # 출력: False

# %% [markdown]
# 6. in과 not in 연산자
# * in 연산자는 요소가 시퀀스(리스트, 튜플, 문자열 등)에 포함되어 있는지 확인합니다.
# * not in은 포함되지 않았는지 확인합니다.

# %%
lst = [1, 2, 3, 4, 5]
print(3 in lst)  # 출력: True
print(6 not in lst)  # 출력: True

text = "Hello"
print("H" in text)  # 출력: True
print("Z" not in text)  # 출력: True

# %% [markdown]
# # 사용자 정의 함수

# %% [markdown]
# 1. 파이썬에서 함수 호출
# * 파이썬에서 함수는 다음과 같은 형식으로 정의하고 호출할 수 있습니다.
#
# 1.1 함수 정의
# * 함수는 def 키워드를 사용하여 정의됩니다.
# * 함수 이름 뒤에 괄호 ()를 사용하고, 인수(매개변수)가 있다면 괄호 안에 정의합니다.
# * 함수 본문은 들여쓰기로 구분하며, return 문을 사용하여 값을 반환할 수 있습니다.

# %%
# 함수 정의
def add_numbers(a, b):
    return a + b

# %% [markdown]
# 1.2 함수 호출
# * 정의된 함수를 호출하려면 함수 이름 뒤에 괄호 ()를 붙이고 필요한 인수를 전달하면 됩니다.

# %%
# 함수 호출
result = add_numbers(5, 7)
print(result)  # 출력: 12

# %% [markdown]
# 1.3 기본값을 갖는 매개변수
# * 함수의 매개변수에 기본값을 지정할 수 있습니다. 함수를 호출할 때 인수를 제공하지 않으면 기본값이 사용됩니다.

# %%
def greet(name="Guest"):
    return f"Hello, {name}!"

print(greet())  # 출력: Hello, Guest!
print(greet("Alice"))  # 출력: Hello, Alice!

# %% [markdown]
# 1.4 키워드 인수
# * 함수를 호출할 때, 위치에 의존하지 않고 매개변수 이름을 사용하여 값을 전달할 수 있습니다.

# %%
def display_info(name, age):
    print(f"Name: {name}, Age: {age}")

display_info(age=25, name="John")  # 출력: Name: John, Age: 25

# %% [markdown]
# 1.5 여러 개의 값을 반환
#
# * 파이썬에서 함수가 여러 값을 반환하려면, 각 값을 쉼표로 구분하여 return 문에서 나열하면 됩니다. 파이썬은 자동으로 이 값들을 튜플로 묶어서 반환합니다.

# %%
def calculate(a, b):
    sum_result = a + b
    product_result = a * b
    return sum_result, product_result  # 여러 값 반환

# 함수 호출
result_sum, result_product = calculate(5, 10)
print(result_sum)  # 출력: 15
print(result_product)  # 출력: 50

# %%
def get_person_info():
    name = "John"
    age = 30
    city = "New York"
    return name, age, city  # 여러 값 반환

# 튜플로 반환값 받기
info = get_person_info()
print(info)  # 출력: ('John', 30, 'New York')

# 개별 요소에 접근
print(info[0])  # 출력: John
print(info[1])  # 출력: 30

# %% [markdown]
# 1.5.1 리스트나 딕셔너리로 여러 값 반환
#
# * 파이썬은 여러 값을 반환할 때, 리스트나 딕셔너리 형태로도 반환할 수 있습니다. 이러한 자료형을 사용하면 튜플보다 더 유연하게 데이터를 관리할 수 있습니다.

# %%
def get_scores():
    return [90, 85, 78]  # 리스트로 반환

scores = get_scores()
print(scores)  # 출력: [90, 85, 78]

# %%
def get_student_info():
    return {"name": "Alice", "age": 25, "major": "Physics"}  # 딕셔너리로 반환

student = get_student_info()
print(student)  # 출력: {'name': 'Alice', 'age': 25, 'major': 'Physics'}

# 딕셔너리 키를 사용하여 값에 접근
print(student['name'])  # 출력: Alice

# %% [markdown]
# 2. 입출력 함수
# * 파이썬에서 데이터를 입력받거나 출력하는 함수는 다음과 같습니다.
#
# 2.1 print() 함수
# * print() 함수는 콘솔에 데이터를 출력하는 함수입니다.
# * 여러 개의 값을 쉼표로 구분하여 출력할 수 있으며, 출력 사이에 들어갈 구분자는 sep 인수로, 출력 후 마지막에 들어갈 문자는 end 인수로 지정할 수 있습니다.

# %%
# 기본 출력
print("Hello, World!")  # 출력: Hello, World!

a = 5
# 여러 값을 출력
print("The sum of", a, "and", 7, "is", 5 + 7)  # 출력: The sum of 5 and 7 is 12

# sep과 end 사용
print("apple", "banana", "cherry", sep=", ", end="!\n")
# 출력: apple, banana, cherry!

# %% [markdown]
# 2.2 input() 함수
# * input() 함수는 사용자의 입력을 받는 함수입니다.
# * 입력된 값은 항상 문자열로 반환되므로 필요하면 형변환이 필요합니다.

# %%
# 입력 받기
name = input("Enter your name: ")
print(f"Hello, {name}!")
print("Hello", name, "!")

# 숫자를 입력받아 덧셈하기
num1 = input("Enter a number: ")
um2 = input("Enter another number: ")
print(f"The sum is: {num1 + num2}")

# %%
# 숫자를 입력받아 덧셈하기
num1 = float(input("Enter a number: "))
num2 = float(input("Enter another number: "))
print("The sum is: ", num1 + num2)

# %% [markdown]
# # 반복과 제어
#
# ## 1. 제어 구조 (조건문)
# 1.1 if, elif, else
# * if 문은 조건을 평가하여 참일 때 실행할 코드 블록을 정의합니다.
# * "elif"는 추가적인 조건을 평가할 때 사용됩니다.
# * "else"는 앞선 조건들이 모두 거짓일 때 실행됩니다.

# %%
x = 10

if x > 10:
    print("x는 10보다 큽니다.")
elif x == 10:
    print("x는 10입니다.")
else:
    print("x는 10보다 작습니다.")
# 출력: x는 10입니다.

# %% [markdown]
# 1.2 중첩된 조건문
# * 조건문은 중첩될 수 있습니다. 즉, if 블록 안에 또 다른 if 문을 사용할 수 있습니다.

# %%
x = 20
y = 30

if x > 10:
    if y > 20:
        print("x는 10보다 크고, y는 20보다 큽니다.")
# 출력: x는 10보다 크고, y는 20보다 큽니다.

# %% [markdown]
# 1.3 단일 라인의 조건문
# * 파이썬은 삼항 연산자(ternary operator)를 사용하여 단일 라인에서 조건을 평가할 수 있습니다.

# %%
# 조건이 참일 때의 값 if 조건 else 조건이 거짓일 때의 값
result = "Positive" if x > 0 else "Negative"
print(result)
# 출력: Positive

# %% [markdown]
# ## 2. 반복문
# * 파이썬에서 반복문은 특정 코드 블록을 여러 번 실행할 때 사용됩니다.
#
# 2.1 for 반복문
# * for 문은 반복 가능한 객체(리스트, 튜플, 문자열 등)를 순회하며 각 요소에 대해 코드 블록을 실행합니다.

# %%
# 리스트 순회
numbers = [1, 2, 3, 4, 5]
for num in range(len(numbers)):
    print(num, end="")
# 출력: 1 2 3 4 5
print()
# 문자열 순회
for char in "Hello":
    print(char)
# 출력: H e l l o

# %% [markdown]
# * range() 함수를 사용하여 일정 범위의 숫자를 생성하고 반복할 수 있습니다.

# %%
# 0부터 4까지 반복
for i in range(5,0,-1):
    print(i)
# 출력: 0 1 2 3 4

# %% [markdown]
# 2.2 while 반복문
# * while 문은 주어진 조건이 참인 동안 계속해서 코드를 실행합니다.
# * 조건이 거짓이 되면 반복이 종료됩니다.

# %%
i = 1
while i <= 5:
    print(i)
    i += 1
# 출력: 1 2 3 4 5
i = 1
for j in range(1,6):
    print(i)
    i += 1

# %% [markdown]
# ## 3. 반복 제어문
# * 파이썬에서 반복문 내의 흐름을 제어하는 명령어는 다음과 같습니다.
#
# 3.1 break
# * break는 반복문을 즉시 종료하고 반복문 밖으로 나갑니다.

# %%
for i in range(10):
    if i == 5:
        break
    print(i)
# 출력: 0 1 2 3 4

# %% [markdown]
# 3.2 continue
# * continue는 현재 반복을 건너뛰고, 다음 반복을 진행합니다.

# %%
for i in range(5):
    if i == 2:
        continue
    print(i)
# 출력: 0 1 3 4

# %% [markdown]
# 3.3 pass
# * pass는 실행할 코드가 없다는 의미로, 문법적으로 블록이 필요하지만 실행할 코드를 넣지 않을 때 사용합니다.

# %%
for i in range(5):
    if i == 2:
        pass  # 아무 작업도 하지 않음
    else:
        print(i)
# 출력: 0 1 3 4

# %% [markdown]
# 4. else와 반복문
# * for 또는 while 반복문에 else 절을 사용할 수 있습니다. 반복문이 정상적으로 종료될 때 실행됩니다. break에 의해 반복문이 종료되면 else는 실행되지 않습니다.

# %%
for i in range(5):
    print(i)
else:
    print("반복문이 정상적으로 종료되었습니다.")
# 출력: 0 1 2 3 4
#       반복문이 정상적으로 종료되었습니다.

for i in range(5):
    if i == 3:
        break
    print(i)
else:
    print("정상 종료")
# 출력: 0 1 2 (else는 실행되지 않음)

# %% [markdown]
# ## 컬렉션 자료형
#
# 파이썬의 컬렉션 자료형은 여러 값을 하나의 변수에 저장할 수 있도록 도와줍니다. 주로 사용하는 컬렉션 자료형은 리스트(list), 튜플(tuple), 집합(set), **딕셔너리(dictionary)**입니다. 각각의 자료형은 고유한 특성과 사용법을 가지고 있습니다.

# %% [markdown]
# ### 1. 리스트 (List)
# * 리스트는 순서가 있으며 변경 가능한(mutable) 데이터 타입입니다.
# * 다양한 데이터 타입을 함께 저장할 수 있습니다.
# "대괄호 []"로 정의하며, 요소는 쉼표로 구분합니다.

# %%
# 리스트 생성
fruits = ["apple", "banana", "cherry"]
print(fruits)  # 출력: ['apple', 'banana', 'cherry']

# 리스트 요소 접근
print(fruits[1])  # 출력: banana

# 리스트 요소 변경
fruits[1] = "blueberry"
print(fruits)  # 출력: ['apple', 'blueberry', 'cherry']

# 리스트에 요소 추가
fruits.append("orange")
print(fruits)  # 출력: ['apple', 'blueberry', 'cherry', 'orange']

# 리스트 요소 삭제
fruits.remove("blueberry")
print(fruits)  # 출력: ['apple', 'cherry', 'orange']

# %% [markdown]
# 주요 리스트 메서드:
# * append(): 리스트 끝에 요소 추가
# * remove(): 특정 요소 삭제
# * insert(): 특정 위치에 요소 삽입
# * pop(): 마지막 요소 또는 지정한 위치의 요소 제거

# %% [markdown]
# ### 2.  튜플 (Tuple)
# * 튜플은 순서가 있으며 변경할 수 없는(immutable) 데이터 타입입니다.
# * "소괄호 ()"로 정의하며, 요소는 쉼표로 구분합니다.
# * 읽기 전용 데이터 구조로 사용됩니다.
# * 튜플은 변경 불가능하므로 요소를 추가하거나 삭제할 수 없습니다.

# %%
# 튜플 생성
coordinates = (10, 20)
print(coordinates)  # 출력: (10, 20)

# 튜플 요소 접근
print(coordinates[0])  # 출력: 10

# 튜플 요소 변경 불가 (오류 발생)
# coordinates[0] = 15  # 오류: TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# 3. 집합 (Set)
# * 집합은 순서가 없고 중복을 허용하지 않는 데이터 타입입니다.
# * "중괄호 {}"로 정의하며, 요소는 쉼표로 구분합니다.
# *  중복된 요소를 자동으로 제거하고, 순서가 없기 때문에 인덱싱으로 접근할 수 없습니다.

# %%
# 집합 생성
numbers = {1, 2, 3, 4, 4, 5}
print(numbers)  # 출력: {1, 2, 3, 4, 5} (중복된 4는 하나만 저장됨)

# 집합에 요소 추가
numbers.add(6)
print(numbers)  # 출력: {1, 2, 3, 4, 5, 6}

# 집합에서 요소 삭제
numbers.remove(3)
print(numbers)  # 출력: {1, 2, 4, 5, 6}

# %% [markdown]
# 주요 집합 메서드:
#
# * add(): 요소 추가
# * remove(): 요소 삭제
# * union(): 두 집합의 합집합 반환
# * intersection(): 두 집합의 교집합 반환
# * difference(): 두 집합의 차집합 반환

# %% [markdown]
# 4. 딕셔너리 (Dictionary)
# * 딕셔너리는 키와 값의 쌍으로 데이터를 저장하는 자료형입니다.
# "중괄호 {}"로 정의하며, 각 쌍은 키":" 값 형태로 저장됩니다.
# * 키는 고유해야 하며, 변경 불가능한 데이터 타입이어야 합니다 (보통 문자열이나 숫자가 많이 사용됩니다).

# %%
# 딕셔너리 생성
person = {
    "name": "John",
    "age": 30,
    "city": "New York"
}
print(person)  # 출력: {'name': 'John', 'age': 30, 'city': 'New York'}

# 딕셔너리에서 값에 접근
print(person["name"])  # 출력: John

# 딕셔너리에서 값 변경
person["age"] = 31
print(person)  # 출력: {'name': 'John', 'age': 31, 'city': 'New York'}

# 딕셔너리에 새로운 키-값 추가
person["job"] = "Engineer"
print(person)  # 출력: {'name': 'John', 'age': 31, 'city': 'New York', 'job': 'Engineer'}

# 딕셔너리에서 요소 삭제
del person["city"]
print(person)  # 출력: {'name': 'John', 'age': 31, 'job': 'Engineer'}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 변수의 범위
#
# 파이썬에서 **변수의 범위(scope)**는 변수에 접근할 수 있는 영역을 의미합니다. 변수의 범위는 주로 **전역 변수(Global Variables)**와 **지역 변수(Local Variables)**로 나뉩니다. 이 범위는 프로그램의 흐름에서 변수의 유효성을 결정하는 중요한 요소입니다.

# %% [markdown]
# 1. 전역 변수 (Global Variables)
#
# 전역 변수는 함수 바깥에서 정의된 변수로, 프로그램 전체에서 접근할 수 있습니다.
# 프로그램이 종료되기 전까지 모든 함수와 코드 블록에서 사용할 수 있습니다.

# %%
x = 10  # 전역 변수

def print_x():
    print(x)  # 함수 내부에서 전역 변수에 접근

print_x()  # 출력: 10

# 함수 외부에서 정의된 변수 x는 전역 변수로, print_x() 함수 내부에서도 접근할 수 있습니다.

# %% [markdown]
# 2. 지역 변수 (Local Variables)
#
# 지역 변수는 함수 내부에서 정의된 변수로, 해당 함수 내에서만 유효합니다.
# 함수가 종료되면 지역 변수는 소멸하며, 함수 외부에서는 접근할 수 없습니다

# %%
y = 10
def my_function():
    y = 5  # 지역 변수
    print(y)

my_function()  # 출력: 5
print(y)  # 오류 발생: NameError: name 'y' is not defined

# my_function() 내부에서 정의된 변수 y는 지역 변수이며, 함수 외부에서는 사용할 수 없기 때문에, 함수 밖에서 y를 출력하려고 하면 오류가 발생합니다.

# %% [markdown]
# 3. 전역 변수와 지역 변수의 관계
#
# 함수 내에서 같은 이름의 변수가 정의되면, 해당 변수는 지역 변수로 취급됩니다. 함수 내에서만 해당 변수에 접근할 수 있으며, 전역 변수는 가려집니다

# %%
x = 10  # 전역 변수

def my_function():
    x = 5  # 지역 변수
    print(x)  # 지역 변수가 출력됨

my_function()  # 출력: 5
print(x)  # 출력: 10 (전역 변수)

# 함수 my_function() 내에서 x라는 지역 변수를 정의했기 때문에, 함수 내부에서는 지역 변수 x가 사용되고, 함수 외부에서는 전역 변수 x가 사용됩니다.

# %% [markdown]
# 4. global 키워드
#
# 함수 내부에서 전역 변수의 값을 변경하려면 global 키워드를 사용해야 합니다.
# global 키워드는 함수 내부에서 전역 변수를 수정할 수 있도록 합니다.

# %%
x = 10  # 전역 변수

def modify_global():
    global x  # 전역 변수 x를 사용
    x = 20  # 전역 변수의 값을 변경
    print(x)  # 출력: 20

modify_global()
print(x)  # 출력: 20 (전역 변수의 값이 변경됨)

# %% [markdown]
# 5. 변수의 범위 규칙 (LEGB 규칙)
#
# 파이썬은 변수를 찾을 때 LEGB 규칙을 따릅니다. 이는 변수가 어떤 범위에 있는지 확인할 때 참조하는 순서를 의미합니다.
#
# * L (Local): 가장 안쪽 함수나 코드 블록의 지역 변수.
# * E (Enclosing): 중첩 함수의 외부 함수에 있는 변수.
# * G (Global): 모듈의 전역 변수.
# * B (Built-in): 파이썬의 내장 함수나 변수.

# %%
x = "global"

def outer_function():
    x = "enclosing"

    def inner_function():
        x = "local"
        print(x)  # 가장 가까운 'local' 변수를 참조

    inner_function()

outer_function()  # 출력: local

# %% [markdown]
# # 파이썬에서의 클래스
#
# **클래스(Class)**는 파이썬에서 객체 지향 프로그래밍(OOP)을 구현하는 기본적인 단위입니다. 클래스는 객체를 정의하는 **템플릿(청사진)**으로, **속성(Attributes)**과 **메서드(Methods)**를 포함할 수 있습니다. 클래스를 사용하면 코드의 재사용성을 높이고, 데이터를 더 구조적으로 관리할 수 있습니다.

# %% [markdown]
# 1. 클래스 정의와 객체 생성
# * 클래스는 class 키워드를 사용하여 정의됩니다.
# * 클래스를 정의한 후에는 이를 기반으로 객체를 생성할 수 있습니다. 객체는 클래스의 인스턴스(instance)입니다.

# %% [markdown]
# 클래스 정의 예시:

# %%
class Person:
    # 클래스의 생성자 (객체 생성 시 호출)
    def __init__(self, name, age):
        self.name = name  # 인스턴스 변수
        self.age = age    # 인스턴스 변수

    # 메서드 정의
    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

# %% [markdown]
# 객체 생성:
#
# * __init__ 메서드는 **생성자(Constructor)**로, 객체가 생성될 때 호출되며, 객체의 초기 상태를 설정합니다.
# * self는 클래스의 인스턴스를 가리키며, 인스턴스 변수를 정의할 때 사용됩니다. self는 파이썬에서 자동으로 전달되지만, 메서드를 정의할 때는 명시적으로 첫 번째 인수로 선언해야 합니다.

# %%
# Person 클래스의 객체 생성
person1 = Person("Alice", 30)
person2 = Person("Bob", 25)

# 객체의 메서드 호출
person1.greet()  # 출력: Hello, my name is Alice and I am 30 years old.
person2.greet()  # 출력: Hello, my name is Bob and I am 25 years old.

# %% [markdown]
# 2. 클래스 속성과 인스턴스 속성
# * 클래스 속성(Class Attributes): 모든 인스턴스에서 공유되는 변수. 클래스 전체에서 동일한 값을 유지합니다.
# * 인스턴스 속성(Instance Attributes): 각 인스턴스별로 고유한 값을 가지는 변수. 객체마다 독립적인 값을 가집니다.

# %%
class Dog:
    # 클래스 속성 (모든 인스턴스가 공유)
    species = "Canis lupus familiaris"

    def __init__(self, name, age):
        # 인스턴스 속성 (각 인스턴스가 고유하게 가짐)
        self.name = name
        self.age = age

# 객체 생성
dog1 = Dog("Buddy", 5)
dog2 = Dog("Charlie", 3)

# 클래스 속성 접근
print(dog1.species)  # 출력: Canis lupus familiaris
print(dog2.species)  # 출력: Canis lupus familiaris

# 인스턴스 속성 접근
print(dog1.name)  # 출력: Buddy
print(dog2.name)  # 출력: Charlie

# %% [markdown]
# 3. 메서드
#
# * 인스턴스 메서드: 객체의 상태(인스턴스 변수)를 변경하거나 읽는 메서드입니다. self를 첫 번째 인수로 받아야 합니다.
# * 클래스 메서드: 클래스 자체에 적용되는 메서드로, @classmethod 데코레이터를 사용하고 첫 번째 인수로 cls(클래스)를 받습니다.
# * 정적 메서드: 클래스나 인스턴스와 관련 없이 동작하는 메서드입니다. @staticmethod 데코레이터를 사용하여 정의하며, self나 cls를 받지 않습니다.

# %%
class Circle:
    pi = 3.14159  # 클래스 속성

    def __init__(self, radius):
        self.radius = radius  # 인스턴스 속성

    # 인스턴스 메서드
    # 인스턴스 메서드는 인스턴스 변수를 이용해 동작하며, 객체마다 다른 동작을 수행할 수 있습니다.
    def area(self):
        return Circle.pi * self.radius ** 2

    # 클래스 메서드
    # 클래스 메서드는 클래스 자체를 첫 번째 인자로 받는 메서드입니다. 클래스 메서드를 정의할 때는 메서드 위에 @classmethod 데코레이터를 사용합니다.
    # 클래스 메서드의 첫 번째 인자는 **cls**로, 이는 해당 메서드를 호출한 클래스 객체를 나타냅니다.
    # 클래스 메서드는 주로 클래스 상태나 클래스 변수를 수정하거나 접근할 때 사용합니다
    @classmethod
    def from_diameter(cls, diameter):
        return cls(diameter / 2)

    # 정적 메서드
    # 정적 메서드는 클래스와 무관한 독립적인 작업을 수행합니다.
    @staticmethod
    def is_positive(number):
        return number > 0

# 인스턴스 생성
circle = Circle(5)
print(circle.area())  # 출력: 78.53975

# 클래스 메서드로 인스턴스 생성
# 클래스 메서드는 클래스 전체에 영향을 미치며, 보통 객체 생성과 관련된 메서드에서 많이 사용됩니다.
circle_from_diameter = Circle.from_diameter(10)
print(circle_from_diameter.radius)  # 출력: 5.0

# 정적 메서드 호출
# 정적 메서드는 클래스와 무관한 독립적인 작업을 수행합니다.
print(Circle.is_positive(-5))  # 출력: False

# %%
class MyClass:
    class_variable = 0

    @classmethod
    def class_method(cls):
        cls.class_variable += 1
        print(f'클래스 변수: {cls.class_variable}')

MyClass.class_method()  # 클래스 메서드 호출
MyClass.class_method()  # 클래스 메서드 호출
myclass = MyClass()
print(myclass.class_variable)

# %% [markdown]
# 4. 상속(Inheritance)
# * 상속은 기존 클래스를 재사용하여 새로운 클래스를 만드는 방법입니다. 상속받은 클래스는 부모 클래스의 모든 속성과 메서드를 물려받으며, 이를 확장하거나 재정의할 수 있습니다.
# * 부모 클래스를 상속받은 클래스를 자식 클래스라고 합니다.

# %%
# 부모 클래스
class Animal:
    def __init__(self, name):
        self.name = name

    def speak(self):
        return "Some sound"

# 자식 클래스 (Animal을 상속)
class Dog(Animal):
    def speak(self):
        return "Woof!"

# 자식 클래스 (Animal을 상속)
class Cat(Animal):
    def speak(self):
        return "Meow!"

# Animal 객체 생성
ani = Animal("dog")
print(ani.name)
print(ani.speak())

# 객체 생성
dog = Dog("Buddy")
cat = Cat("Whiskers")

print(dog.name)  # 출력: Buddy
print(dog.speak())  # 출력: Woof!
print(cat.speak())  # 출력: Meow!

# %% [markdown]
# * Dog와 Cat 클래스는 Animal 클래스를 상속받아 부모 클래스의 속성을 물려받습니다.
# * speak() 메서드는 각 자식 클래스에서 재정의(override) 되어 고유한 동작을 수행합니다.

# %% [markdown]
# 5. 다형성(Polymorphism)
# * 다형성은 동일한 이름의 메서드가 다른 클래스에서 다른 방식으로 동작하는 것을 의미합니다.
# * 예를 들어, 부모 클래스에서 정의된 메서드를 자식 클래스에서 재정의(오버라이딩)할 수 있으며, 서로 다른 클래스의 객체들이 동일한 인터페이스로 상호작용할 수 있습니다.

# %%
def animal_sound(animal):
    print(animal.speak())

dog = Dog("Buddy")
cat = Cat("Whiskers")

animal_sound(dog)  # 출력: Woof!
animal_sound(cat)  # 출력: Meow!

# %% [markdown]
# * animal_sound() 함수는 Dog와 Cat 객체를 동일하게 처리하지만, 각각의 객체에서 재정의된 speak() 메서드를 호출합니다.

# %% [markdown]
# 6. 캡슐화(Encapsulation)과 접근 제어
# * 캡슐화는 객체의 내부 데이터를 외부에서 직접 접근하지 못하도록 제한하는 기법입니다.
# * 파이썬에서 변수나 메서드 이름 앞에 밑줄 _ 또는 **이중 밑줄 __**을 붙여서 접근 제어를 할 수 있습니다.
# * 단일 밑줄 _: 내부 사용을 의미하는 관례로, 직접 사용하지 말라는 의미.
# * 이중 밑줄 __: **이름 맹글링(name mangling)**을 통해 외부에서 접근하지 못하게 합니다.

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self._age = age  # 관례상 비공개 변수

    def get_age(self):
        return self._age

    def set_age(self, age):
        if age > 0:
            self._age = age

# 객체 생성
person = Person("John", 30)

# 비공개 변수 접근 (관례상 직접 접근하지 않음)
print(person._age)  # 출력: 30

# Getter와 Setter 사용
person.set_age(35)
print(person.get_age())  # 출력: 35
